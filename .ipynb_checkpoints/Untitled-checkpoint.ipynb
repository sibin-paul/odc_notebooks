# %%
import datacube
from utils.dea_tools.datahandling import mostcommon_crs

# %%
dc = datacube.Datacube(app = 'test_app')

# %%
dc.list_products()
# Out:
#                                                   name  \
# name
# io_lulc                                        io_lulc
# ls5_nbart_geomedian_annual  ls5_nbart_geomedian_annual
# ls5_sr                                          ls5_sr
# ls7_nbart_geomedian_annual  ls7_nbart_geomedian_annual
# ls8_c01_l1_product                  ls8_c01_l1_product
# ls8_c01_l1_qa_product            ls8_c01_l1_qa_product
# ls8_c01_l2_usgs_sr_scene      ls8_c01_l2_usgs_sr_scene
# ls8_level1_usgs                        ls8_level1_usgs
# ls8_nbart_geomedian_annual  ls8_nbart_geomedian_annual
# ls8_sr                                          ls8_sr
# ls8_st                                          ls8_st
# ls8_usgs_sr_scene                    ls8_usgs_sr_scene
# nasadem                                        nasadem
# s1_rtc                                          s1_rtc
# s2_l2a                                          s2_l2a
#
# ...

# %%
dc.list_measurements()
# Out:
#                                          name   dtype units  nodata  \
# product                    measurement
# io_lulc                    data          data   uint8     1     0.0
# ls5_nbart_geomedian_annual blue          blue   int16     1  -999.0
#                            green        green   int16     1  -999.0
#                            red            red   int16     1  -999.0
#                            nir            nir   int16     1  -999.0
# ...                                       ...     ...   ...     ...
# s2_l2a                     B11            B11  uint16     1     0.0
#                            B12            B12  uint16     1     0.0
#                            SCL            SCL   uint8     1     0.0
#                            AOT            AOT  uint16     1     0.0
#                            WVP            WVP  uint16     1     0.0
#
#                                                              aliases  \
# ...

# %%
product='ls8_level1_usgs',
platform="LANDSAT_8"
lat, lon = 14.4595, 74.4799
buffer = 0.05
latitude = (lat - buffer, lat + buffer)
longitude = (lon - buffer, lon + buffer)
resolution = (-30, 30)
time_extents = ('2021-04-01')

query=dict(latitude=latitude,
           longitude=longitude,
           time=time_extents)

output_crs = mostcommon_crs(dc=dc, product=product, query=query)

# %%
ds = dc.load(product=product, 
             output_crs=output_crs, 
             resolution=resolution, 
             **query)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 1, x: 361, y: 370)
# Coordinates:
#   * time             (time) datetime64[ns] 2021-04-01T05:22:36.586044
#   * y                (y) float64 1.604e+06 1.604e+06 ... 1.593e+06 1.593e+06
#   * x                (x) float64 4.386e+05 4.386e+05 ... 4.493e+05 4.494e+05
#     spatial_ref      int32 32643
# Data variables:
#     coastal_aerosol  (time, y, x) int16 10464 10479 10452 ... 10294 10374 10289
#     blue             (time, y, x) int16 9520 9566 9533 9464 ... 9284 9424 9300
#     green            (time, y, x) int16 8914 8992 9005 8856 ... 8662 8840 8697
#     red              (time, y, x) int16 8031 8214 8207 8029 ... 7790 8269 7864
#     nir              (time, y, x) int16 16872 16559 16251 ... 17884 16890 17925
#     swir1            (time, y, x) int16 13185 13592 13612 ... 12386 12903 12449
#     swir2            (time, y, x) int16 9007 9508 9458 9148 ... 8333 8726 8368
# ...

# %%
rgb(ds, index=0)

# %%
ds = dc.load(product='ls8_c01_l2_usgs_sr_scene', output_crs='EPSG:32643',resolution=(-30, 30))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_659/614596605.py in <module>
#       1 ds = dc.load(product='ls8_c01_l2_usgs_sr_scene', output_crs='EPSG:32643',resolution=(-30, 30))
# ----> 2 rgb(ds)
#
# NameError: name 'rgb' is not defined

# %%
from utils.dea_tools.plotting import rgb
rgb(ds)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 1, x: 5323, y: 4687)
# Coordinates:
#   * time             (time) datetime64[ns] 2021-01-27T05:22:58.430530
#   * y                (y) float64 1.675e+06 1.675e+06 ... 1.535e+06 1.535e+06
#   * x                (x) float64 3.704e+05 3.704e+05 ... 5.3e+05 5.3e+05
#     spatial_ref      int32 32643
# Data variables:
#     coastal_aerosol  (time, y, x) int16 -9999 -9999 -9999 ... -9999 -9999 -9999
#     blue             (time, y, x) int16 -9999 -9999 -9999 ... -9999 -9999 -9999
#     green            (time, y, x) int16 -9999 -9999 -9999 ... -9999 -9999 -9999
#     red              (time, y, x) int16 -9999 -9999 -9999 ... -9999 -9999 -9999
#     nir              (time, y, x) int16 -9999 -9999 -9999 ... -9999 -9999 -9999
#     swir1            (time, y, x) int16 -9999 -9999 -9999 ... -9999 -9999 -9999
#     swir2            (time, y, x) int16 -9999 -9999 -9999 ... -9999 -9999 -9999
# ...
